# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL #Python image library
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "../Deep_Learning_ex/archive/New_Plant/New_Plant/train_plant"
test_dir = "../Deep_Learning_ex/archive/New_Plant/New_Plant/test/"

# %%
sample_generator = ImageDataGenerator(
    rescale = 1./255,
    vertical_flip=True,
    horizontal_flip=True,
    rotation_range=90,
    height_shift_range=0.2,
    width_shift_range=0.2,
    #fill_mode='constant' #there's black pixels
    zoom_range=.30
    #shear_range = 200

        )
sample_images = sample_generator.flow_from_directory(
    train_dir,
    target_size = (300,300),
    color_mode='rgb',
    class_mode= None,
    batch_size=1,
    shuffle=True,
    seed=42
)

# train_generator = ImageDataGenerator(
#     rescale = 1./255,
#     vertical_flip=True,
#     horizontal_flip=True,
#     rotation_range=90,
#     height_shift_range=0.2,
#     width_shift_range=0.2,
#     #fill_mode='constant' #there's black pixels
#     zoom_range=.30
#     #shear_range = 200

#         )

# test_generator = ImageDataGenerator(
#     rescale = 1./255,
#     validation_split = 0.7
#     #shear_range = 200

#         )
# Out:
# Found 70295 images belonging to 38 classes.

# %%
# train_images = train_generator.flow_from_directory(
#     train_dir,
#     target_size = (150,150),
#     color_mode='rgb',
#     class_mode= 'categorical',
#     batch_size=32,
#     shuffle=True,
#     seed=42
# )

# val_images = test_generator.flow_from_directory(
#     test_dir,
#     target_size = (150,150),
#     color_mode='rgb',
#     class_mode= 'categorical',
#     batch_size=32,
#     shuffle=True,
#     seed=42,
#     subset='training'
# )

# test_images = test_generator.flow_from_directory(
#     test_dir,
#     target_size = (150,150),
#     color_mode='rgb',
#     class_mode= 'categorical',
#     batch_size=32,
#     shuffle=False,
#     seed=42,
#     subset='validation'
# )

# %%
sample_images.next()
# Out:
# array([[[[0.50980395, 0.7411765 , 0.6156863 ],
#          [0.50980395, 0.7411765 , 0.6156863 ],
#          [0.50980395, 0.7411765 , 0.6156863 ],
#          ...,
#          [0.45304343, 0.63632566, 0.4354986 ],
#          [0.45692164, 0.6380745 , 0.44629806],
#          [0.44056937, 0.6282632 , 0.4397572 ]],
#
#         [[0.50980395, 0.7411765 , 0.6156863 ],
#          [0.50980395, 0.7411765 , 0.6156863 ],
#          [0.50980395, 0.7411765 , 0.6156863 ],
#          ...,
#          [0.4572329 , 0.6384204 , 0.44387755],
#          [0.4464479 , 0.63179034, 0.4421086 ],
#          [0.44103974, 0.627451  , 0.44286373]],
#
#         [[0.50980395, 0.7411765 , 0.6211978 ],
#          [0.50980395, 0.7411765 , 0.6166982 ],
#          [0.50980395, 0.7411765 , 0.6156863 ],
#          ...,
#          [0.45232645, 0.6353175 , 0.44446   ],
#          [0.439864  , 0.627451  , 0.44051233],
#          [0.44313446, 0.627451  , 0.44705322]],
#
#         ...,
#
# ...

# %%
sample_images.next()[0].shape
# Out:
# (300, 300, 3)

# %%
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i +1)
    img = sample_images.next()[0]
    plt.imshow(img)
    plt.axis('off')

# %%
class_names = [    ]
